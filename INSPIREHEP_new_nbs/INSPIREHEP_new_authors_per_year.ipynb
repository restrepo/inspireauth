# %% [markdown]
# ## Minimal notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import requests

import seaborn as sns

from collections import Counter
import itertools

from matplotlib.colors import LogNorm, SymLogNorm, Normalize
from matplotlib.ticker import MaxNLocator, FormatStrFormatter

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Import database

# %%
# always use False
LOCAL = False

if LOCAL:
    f = open('data/inspire_LA.json','r')
    df = json.load(f)
    f.close()
else:
    r = requests.get('https://github.com/restrepo/inspireauth/raw/main/data/inspire_LA.json')
    df = r.json()

db_master = pd.DataFrame(df)
db_master.head()
# Out:
#           author_id    country  \
# 0      H.Albrecht.1  Venezuela
# 1         D.M.B.R.1  Venezuela
# 2   D.F.Mundarain.1      Chile
# 3        R.Gaitan.2  Venezuela
# 4  J.Ntahompagaze.1     Rwanda
#
#                                      email_addresses              full_name  \
# 0  [{'value': 'hartwig.albrecht@desy.de', 'curren...      Albrecht, Hermann
# 1                                               None        Bellorin, David
# 2                                               None  Mundarain, Douglas F.
# 3  [{'value': 'rgaitan@uc.edu.ve', 'current': Fal...     Dominguez, Yessica
# 4                                               None   Ntahompagaze, Joseph
#
#                                                  ids            institution  \
# 0  [{'value': 'H.Albrecht.1', 'schema': 'INSPIRE ...           Unlisted, VE
# 1  [{'value': 'D.M.B.R.1', 'schema': 'INSPIRE BAI'}]           Unlisted, VE
# 2  [{'value': 'D.F.Mundarain.1', 'schema': 'INSPI...  Catolica del Norte U.
# 3  [{'value': 'R.Gaitan.2', 'schema': 'INSPIRE BA...           Unlisted, VE
# 4  [{'value': 'J.Ntahompagaze.1', 'schema': 'INSP...          EAIFR, Kigali
#
#   institution_id                                               name  \
# 0         912061  {'value': 'Albrecht, Hartwig', 'preferred_name...
# 1         912061                 {'value': 'R., David M. Bellorin'}
# 2         908143                 {'value': 'Mundarain, Douglas F.'}
# 3         912061  {'value': 'Gaitan, Rolando', 'preferred_name':...
# 4        1636656                  {'value': 'Ntahompagaze, Joseph'}
#
#                                               papers  \
# 0  [{'recid': 2023395, 'year': '2021', 'citation_...
# 1  [{'recid': 2023395, 'year': '2021', 'citation_...
# 2  [{'recid': 2023395, 'year': '2021', 'citation_...
# 3  [{'recid': 1863076, 'year': '2021', 'citation_...
# 4  [{'recid': 2087212, 'year': '2022', 'citation_...
#
#                                            positions profile_id advisors
# 0  [{'record': {'$ref': 'https://inspirehep.net/a...    1018731       []
# 1                                               None    2023397       []
# 2                                               None    2023398       []
# 3  [{'rank': 'PHD', 'record': {'$ref': 'https://i...    1864347       []
# 4                                               None    2087213       []

# %% [markdown]
# # All countries in the database

# %%
# find all countries in json
all_countries = db_master['country'].unique()
# get rid of Nonetypes in the database
all_countries = [country for country in all_countries if country is not None]
# sort countries 
all_countries.sort()

print(len(all_countries))

for country in all_countries:
    print(country)
    
# format country 
def format_country(country):
    country = country.lower()
    ans = country.replace(" ", "_")
    return ans
# Out:
# 115
# Algeria
# Argentina
# Armenia
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bangladesh
# Belarus
# Belgium
# Benin
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Brazil
# Brunei Darussalam
# Bulgaria
# Canada
# Chile
# China
# Colombia
# Congo
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czechia
# Denmark
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Estonia
# Ethiopia
# Finland
# France
# Georgia
# Germany
# Ghana
# Greece
# Guatemala
# Holy See (Vatican City State)
# Honduras
# Hungary
# Iceland
# India
# Indonesia
# Iran, Islamic Republic of
# Iraq
# Ireland
# Israel
# Italy
# Jamaica
# Japan
# Jordan
# Kazakhstan
# Korea, Republic of
# Kuwait
# Kyrgyzstan
# Latvia
# Lebanon
# Lithuania
# Luxembourg
# Madagascar
# Malaysia
# Malta
# Mexico
# Moldova
# Mongolia
# Montenegro
# Morocco
# Netherlands
# New Zealand
# Niger
# Nigeria
# North Macedonia
# Norway
# Oman
# Pakistan
# Palestine, State of
# Panama
# Paraguay
# Peru
# Philippines
# Poland
# Portugal
# Puerto Rico
# Qatar
# Romania
# Russian Federation
# Rwanda
# Saudi Arabia
# Serbia and Montenegro
# Singapore
# Slovakia
# Slovenia
# South Africa
# Spain
# Sri Lanka
# Sweden
# Switzerland
# Syrian Arab Republic
# Taiwan
# Thailand
# Tunisia
# Turkey
# Uganda
# Ukraine
# United Arab Emirates
# United Kingdom
# United States
# Uruguay
# Uzbekistan
# Venezuela
# Vietnam

# %% [markdown]
# # Latin American countries

# %%
# 19 Latin American countries indexed in the database
LA_countries = [
    'Argentina',
    'Bolivia',
    'Brazil',
    'Chile',
    'Colombia',
    'Costa Rica',
    'Cuba',
    'Dominican Republic', # new
    'Ecuador',
    'El Salvador', # new
    'Guatemala',
    'Honduras',
    'Mexico',
    'Panama', # new
    'Paraguay',
    'Peru',
    'Puerto Rico', # new
    'Uruguay',
    'Venezuela'
]

# Jamaica, Bahamas not included. 

LA_countries_format = [format_country(country) for country in LA_countries]
print(LA_countries_format)
# Out:
# ['argentina', 'bolivia', 'brazil', 'chile', 'colombia', 'costa_rica', 'cuba', 'dominican_republic', 'ecuador', 'el_salvador', 'guatemala', 'honduras', 'mexico', 'panama', 'paraguay', 'peru', 'puerto_rico', 'uruguay', 'venezuela']

# %%
db_master.head()
db = db_master
db=db[db['country']=='Chile'].reset_index(drop=True)
db.head(20)
# Out:
#                  author_id country  \
# 0          D.F.Mundarain.1   Chile
# 1   M.P.Garcia.del.Moral.1   Chile
# 2            A.Restuccia.1   Chile
# 3            C.Las.Heras.1   Chile
# 4            P.D.Alvarez.1   Chile
# 5               J.H.Pena.1   Chile
# 6              R.R.Prado.1   Chile
# 7               A.Rincon.1   Chile
# 8          F.Tello.Ortiz.1   Chile
# 9                 P.Leon.1   Chile
# 10     M.A.Garcia.Nustes.1   Chile
# 11             J.F.Marin.2   Chile
# 12              S.Duffau.1   Chile
# 13             G.Carraro.1   Chile
# 14            R.A.Mendez.1   Chile
# 15               S.Hoyer.1   Chile
# 16             M.J.Stock.1   Chile
# 17     M.MunozEcheverria.1   Chile
# 18         S.Niklitschek.1   Chile
# 19             A.Delgado.6   Chile
#
#                                       email_addresses  \
# 0                                                None
# 1   [{'value': 'maria.garciadelmoral@uantof.cl', '...
# 2       [{'value': 'arestu@usb.ve', 'current': True}]
# 3                                                None
# 4   [{'value': 'pd.alvarez.n@gmail.com', 'current'...
# 5                                                None
# 6   [{'value': 'raul.prado@desy.de', 'current': Tr...
# 7   [{'value': 'arrincon@uc.cl'}, {'value': 'angel...
# 8                                                None
# 9   [{'value': 'pablo.leon@ua.cl', 'current': False}]
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  [{'value': 'shoyer@berkeley.edu', 'current': T...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
#
#                         full_name  \
# 0           Mundarain, Douglas F.
# 1   Garcia del Moral, Maria Pilar
# 2               Restuccia, Alvaro
# 3                   Las Heras, C.
# 4               Alvarez, Pedro D.
# 5                Peña, Joselen M.
# 6                Prado, Reginaldo
# 7                   Rincón, Angel
# 8          Tello-Ortiz, Francisco
# 9                        Leon, P.
# 10       García-Ñustes, Mónica A.
# 11                 Marín, Juan F.
# 12                  Duffau, Sonia
# 13              Carraro, Giovanni
# 14                Mendez, Rene A.
# 15                      Hoyer, S.
# 16                    Stock, M.J.
# 17                      Muñoz, M.
# 18                Niklitschek, S.
# 19                    Delgado, A.
#
#                                                   ids  \
# 0   [{'value': 'D.F.Mundarain.1', 'schema': 'INSPI...
# 1   [{'value': '0000-0002-3329-2391', 'schema': 'O...
# 2   [{'value': 'A.Restuccia.1', 'schema': 'INSPIRE...
# 3   [{'value': 'C.Las.Heras.1', 'schema': 'INSPIRE...
# 4   [{'value': '0000-0001-8757-1700', 'schema': 'O...
# 5   [{'value': 'J.H.Pena.1', 'schema': 'INSPIRE BA...
# 6   [{'value': '0000-0001-9152-2995', 'schema': 'O...
# 7   [{'value': '0000-0001-8069-9162', 'schema': 'O...
# 8                                                None
# 9   [{'value': 'P.Leon.1', 'schema': 'INSPIRE BAI'...
# 10                                               None
# 11  [{'value': '0000-0003-3756-5016', 'schema': 'O...
# 12                                               None
# 13                                               None
# 14                                               None
# 15  [{'value': 'S.Hoyer.1', 'schema': 'INSPIRE BAI...
# 16                                               None
# 17  [{'value': 'M.MunozEcheverria.1', 'schema': 'I...
# 18  [{'value': 'S.Niklitschek.1', 'schema': 'INSPI...
# 19  [{'value': 'A.Delgado.6', 'schema': 'INSPIRE B...
#
#                 institution institution_id  \
# 0     Catolica del Norte U.         908143
# 1            Antofagasta U.         907784
# 2            Antofagasta U.         907784
# 3            Antofagasta U.         907784
# 4            Antofagasta U.         907784
# 5            Antofagasta U.         907784
# 6            Antofagasta U.         907784
# 7   Valparaiso U., Catolica         904828
# 8            Antofagasta U.         907784
# 9            Antofagasta U.         907784
# 10  Valparaiso U., Catolica         904828
# 11  Valparaiso U., Catolica         904828
# 12       Chile U., Beauchef         909612
# 13       Chile U., Beauchef         909612
# 14       Chile U., Beauchef         909612
# 15       Chile U., Catolica         904336
# 16             Los Andes U.         908733
# 17            Concepcion U.         904435
# 18            Concepcion U.         904435
# 19              Tarapaca U.         907534
#
#                                                  name  \
# 0                  {'value': 'Mundarain, Douglas F.'}
# 1   {'value': 'Garcia del Moral Zabala, Maria del ...
# 2   {'value': 'Restuccia, Alvaro', 'preferred_name...
# 3   {'value': 'las Heras Gouverneur, Camilo', 'nam...
# 4   {'value': 'Alvarez, Pedro Diego', 'preferred_n...
# 5   {'value': 'Pena, J.M.', 'preferred_name': 'J.M...
# 6   {'value': 'Prado, Raul Ribeiro', 'name_variant...
# 7   {'value': 'Rincón, Ángel', 'name_variants': ['...
# 8                                                None
# 9   {'value': 'León, Pablo Enmanuel', 'preferred_n...
# 10                                               None
# 11  {'value': 'Marín, Juan F.', 'preferred_name': ...
# 12                                               None
# 13                                               None
# 14                                               None
# 15  {'value': 'Hoyer, Stephan', 'preferred_name': ...
# 16                                               None
# 17               {'value': 'Muñoz-Echeverría, Miren'}
# 18                       {'value': 'Niklitschek, S.'}
# 19                           {'value': 'Delgado, A.'}
#
#                                                papers  \
# 0   [{'recid': 2023395, 'year': '2021', 'citation_...
# 1   [{'recid': 781916, 'year': '2008', 'citation_c...
# 2   [{'recid': 781916, 'year': '2008', 'citation_c...
# 3   [{'recid': 1602193, 'year': '2018', 'citation_...
# 4   [{'recid': 1859189, 'year': '2022', 'citation_...
# 5   [{'recid': 781916, 'year': '2008', 'citation_c...
# 6   [{'recid': 1859189, 'year': '2022', 'citation_...
# 7   [{'recid': 1797461, 'year': '2020', 'citation_...
# 8   [{'recid': 1797461, 'year': '2020', 'citation_...
# 9   [{'recid': 1705685, 'year': '2019', 'citation_...
# 10  [{'recid': 1630936, 'year': '2018', 'citation_...
# 11  [{'recid': 1630936, 'year': '2018', 'citation_...
# 12  [{'recid': 695685, 'year': '2006', 'citation_c...
# 13  [{'recid': 695685, 'year': '2006', 'citation_c...
# 14  [{'recid': 695685, 'year': '2006', 'citation_c...
# 15  [{'recid': 647400, 'year': '2004', 'citation_c...
# 16  [{'recid': 597861, 'year': '2002', 'citation_c...
# 17  [{'recid': 2047459, 'year': '2022', 'citation_...
# 18  [{'recid': 2047459, 'year': '2022', 'citation_...
# 19  [{'recid': 2047459, 'year': '2022', 'citation_...
#
#                                             positions profile_id  \
# 0                                                None    2023398
# 1   [{'rank': 'SENIOR', 'record': {'$ref': 'https:...    1019914
# 2   [{'record': {'$ref': 'https://inspirehep.net/a...     991923
# 3   [{'rank': 'PHD', 'hidden': False, 'record': {'...    1834568
# 4   [{'rank': 'POSTDOC', 'record': {'$ref': 'https...    1051781
# 5   [{'record': {'$ref': 'https://inspirehep.net/a...    1052800
# 6   [{'rank': 'POSTDOC', 'record': {'$ref': 'https...    1300753
# 7   [{'rank': 'POSTDOC', 'hidden': False, 'record'...    1605701
# 8                                                None       None
# 9   [{'rank': 'PHD', 'record': {'$ref': 'https://i...    1834561
# 10                                               None       None
# 11  [{'record': {'$ref': 'https://inspirehep.net/a...    1844376
# 12                                               None    2229470
# 13                                               None       None
# 14                                               None       None
# 15  [{'rank': 'PHD', 'record': {'$ref': 'https://i...    1051889
# 16                                               None    2416081
# 17                                               None    1959135
# 18                                               None    2047461
# 19                                               None    2047463
#
#                                              advisors
# 0                                                  []
# 1   [{'ids': [{'value': 'INSPIRE-00666347', 'schem...
# 2   [{'ids': [{'value': 'INSPIRE-00130868', 'schem...
# 3   [{'ids': [{'value': 'INSPIRE-00056546', 'schem...
# 4   [{'ids': [{'value': 'INSPIRE-00328995', 'schem...
# 5                                                  []
# 6   [{'ids': [{'value': 'INSPIRE-00150500', 'schem...
# 7   [{'ids': [{'value': 'INSPIRE-00520624', 'schem...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'name': 'Whaley, Birgitta', 'degree_type': '...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []

# %%
db.shape
# Out:
# (2907, 12)

# %%
db = db.drop_duplicates(subset=['author_id'])
db.shape
# Out:
# (2043, 12)

# %%
duplicated_indices = db[db['author_id'].duplicated()].index
# select the first two rows that contain a duplicated entry
result = db.loc[duplicated_indices[:2]]
print(result)
# Out:
# Empty DataFrame
# Columns: [author_id, country, email_addresses, full_name, ids, institution, institution_id, name, papers, positions, profile_id, advisors]
# Index: []

# %%
import pandas as pd

# create a sample dataframe
data = {'column': ['a', 'b', 'c', 'b', 'd', 'e', 'f', 'e']}
df = pd.DataFrame(data)

# get the indices of the duplicated entries in the 'column' column
duplicated_indices = df[df['column'].duplicated()].index

# select the first two rows that contain a duplicated entry
result = df.loc[duplicated_indices[:2]]

# %%
result
# Out:
#   column
# 3      b
# 7      e

# %% [markdown]
# # Total and active authors per year

# %%
# Get number of authors 

def get_number_authors(country):
    # select country
    db=db_master[db_master['country']==country].reset_index(drop=True)
    # remove duplicate authors according to `author_id`
    db = db.drop_duplicates(subset=['author_id'])
    number_of_authors = len(db.index)
    print(f"{country}: {number_of_authors} authors.")
    
for country in LA_countries:
    get_number_authors(country)
