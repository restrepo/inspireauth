# %% [markdown]
# ## Minimal notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import requests

import seaborn as sns

from collections import Counter
import itertools

from matplotlib.colors import LogNorm, SymLogNorm, Normalize
from matplotlib.ticker import MaxNLocator, FormatStrFormatter

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# /Users/manuelmorales/miniconda3/envs/training/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Import database

# %%
# always use False
LOCAL = False

if LOCAL:
    f = open('data/inspire_LA.json','r')
    df = json.load(f)
    f.close()
else:
    r = requests.get('https://github.com/restrepo/inspireauth/raw/main/data/inspire_LA.json')
    df = r.json()

db_master = pd.DataFrame(df)
db_master.head()
# Out:
#           author_id    country  \
# 0      H.Albrecht.1  Venezuela
# 1         D.M.B.R.1  Venezuela
# 2   D.F.Mundarain.1      Chile
# 3        R.Gaitan.2  Venezuela
# 4  J.Ntahompagaze.1     Rwanda
#
#                                      email_addresses              full_name  \
# 0  [{'value': 'hartwig.albrecht@desy.de', 'curren...      Albrecht, Hermann
# 1                                               None        Bellorin, David
# 2                                               None  Mundarain, Douglas F.
# 3  [{'value': 'rgaitan@uc.edu.ve', 'current': Fal...     Dominguez, Yessica
# 4                                               None   Ntahompagaze, Joseph
#
#                                                  ids            institution  \
# 0  [{'value': 'H.Albrecht.1', 'schema': 'INSPIRE ...           Unlisted, VE
# 1  [{'value': 'D.M.B.R.1', 'schema': 'INSPIRE BAI'}]           Unlisted, VE
# 2  [{'value': 'D.F.Mundarain.1', 'schema': 'INSPI...  Catolica del Norte U.
# 3  [{'value': 'R.Gaitan.2', 'schema': 'INSPIRE BA...           Unlisted, VE
# 4  [{'value': 'J.Ntahompagaze.1', 'schema': 'INSP...          EAIFR, Kigali
#
#   institution_id                                               name  \
# 0         912061  {'value': 'Albrecht, Hartwig', 'preferred_name...
# 1         912061                 {'value': 'R., David M. Bellorin'}
# 2         908143                 {'value': 'Mundarain, Douglas F.'}
# 3         912061  {'value': 'Gaitan, Rolando', 'preferred_name':...
# 4        1636656                  {'value': 'Ntahompagaze, Joseph'}
#
#                                               papers  \
# 0  [{'recid': 2023395, 'year': '2021', 'citation_...
# 1  [{'recid': 2023395, 'year': '2021', 'citation_...
# 2  [{'recid': 2023395, 'year': '2021', 'citation_...
# 3  [{'recid': 1863076, 'year': '2021', 'citation_...
# 4  [{'recid': 2087212, 'year': '2022', 'citation_...
#
#                                            positions profile_id advisors  \
# 0  [{'record': {'$ref': 'https://inspirehep.net/a...    1018731       []
# 1                                               None    2023397       []
# 2                                               None    2023398       []
# 3  [{'rank': 'PHD', 'record': {'$ref': 'https://i...    1864347       []
# 4                                               None    2087213       []
#
#     gender     first_names  gender_probability
# 0  unknown         Hartwig                 0.0
# 1     male  David Bellorin                 1.0
# 2     male         Douglas                 1.0
# 3     male         Rolando                 1.0
# 4     male          Joseph                 1.0

# %% [markdown]
# # All countries in the database

# %%
# find all countries in json
all_countries = db_master['country'].unique()
# get rid of Nonetypes in the database
all_countries = [country for country in all_countries if country is not None]
# sort countries 
all_countries.sort()

print(len(all_countries))

for country in all_countries:
    print(country)
    
# format country 
def format_country(country):
    country = country.lower()
    ans = country.replace(" ", "_")
    return ans
# Out:
# 115
# Algeria
# Argentina
# Armenia
# Australia
# Austria
# Azerbaijan
# Bahamas
# Bangladesh
# Belarus
# Belgium
# Benin
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Brazil
# Brunei Darussalam
# Bulgaria
# Canada
# Chile
# China
# Colombia
# Congo
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czechia
# Denmark
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Estonia
# Ethiopia
# Finland
# France
# Georgia
# Germany
# Ghana
# Greece
# Guatemala
# Holy See (Vatican City State)
# Honduras
# Hungary
# Iceland
# India
# Indonesia
# Iran, Islamic Republic of
# Iraq
# Ireland
# Israel
# Italy
# Jamaica
# Japan
# Jordan
# Kazakhstan
# Korea, Republic of
# Kuwait
# Kyrgyzstan
# Latvia
# Lebanon
# Lithuania
# Luxembourg
# Madagascar
# Malaysia
# Malta
# Mexico
# Moldova
# Mongolia
# Montenegro
# Morocco
# Netherlands
# New Zealand
# Niger
# Nigeria
# North Macedonia
# Norway
# Oman
# Pakistan
# Palestine, State of
# Panama
# Paraguay
# Peru
# Philippines
# Poland
# Portugal
# Puerto Rico
# Qatar
# Romania
# Russian Federation
# Rwanda
# Saudi Arabia
# Serbia and Montenegro
# Singapore
# Slovakia
# Slovenia
# South Africa
# Spain
# Sri Lanka
# Sweden
# Switzerland
# Syrian Arab Republic
# Taiwan
# Thailand
# Tunisia
# Turkey
# Uganda
# Ukraine
# United Arab Emirates
# United Kingdom
# United States
# Uruguay
# Uzbekistan
# Venezuela
# Vietnam

# %% [markdown]
# # Latin American countries

# %%
# 19 Latin American countries indexed in the database
LA_countries = [
    'Argentina',
    'Bolivia',
    'Brazil',
    'Chile',
    'Colombia',
    'Costa Rica',
    'Cuba',
    'Dominican Republic', # new
    'Ecuador',
    'El Salvador', # new
    'Guatemala',
    'Honduras',
    'Mexico',
    'Panama', # new
    'Paraguay',
    'Peru',
    #'Puerto Rico', # removed
    'Uruguay',
    'Venezuela'
]

# Jamaica, Bahamas not included. 

LA_countries_format = [format_country(country) for country in LA_countries]

# %% [markdown]
# # Small test

# %%
db_test = db_master[db_master['country']=='Dominican Republic'].reset_index(drop=True)
db_test.head()
# Out:
#            author_id             country  \
# 0  Daniel.Sudarsky.1  Dominican Republic
# 1  Daniel.Sudarsky.1  Dominican Republic
#
#                                      email_addresses         full_name  \
# 0  [{'value': 'sudarsky@nucleares.unam.mx', 'curr...  Sudarsky, Daniel
# 1  [{'value': 'sudarsky@nucleares.unam.mx', 'curr...      Sudarsky, D.
#
#                                                  ids  \
# 0  [{'value': 'I4AlvWAAAAAJ', 'schema': 'GOOGLESC...
# 1  [{'value': 'I4AlvWAAAAAJ', 'schema': 'GOOGLESC...
#
#                   institution institution_id  \
# 0        Santo Domingo, PUCMM         906531
# 1  Santo Domingo, Autonoma U.         907039
#
#                                                 name  \
# 0  {'value': 'Sudarsky, Daniel', 'name_variants':...
# 1  {'value': 'Sudarsky, Daniel', 'name_variants':...
#
#                                               papers  \
# 0  [{'recid': 35032, 'year': '1993', 'citation_co...
# 1  [{'recid': 35032, 'year': '1993', 'citation_co...
#
#                                            positions profile_id  \
# 0  [{'rank': 'SENIOR', 'record': {'$ref': 'https:...     987260
# 1  [{'rank': 'SENIOR', 'record': {'$ref': 'https:...     987260
#
#                                             advisors gender first_names  \
# 0  [{'ids': [{'value': 'INSPIRE-00081421', 'schem...   male      Daniel
# 1  [{'ids': [{'value': 'INSPIRE-00081421', 'schem...   male      Daniel
#
#    gender_probability
# 0                 1.0
# 1                 1.0

# %%
inst_list = db_test['institution_id'].drop_duplicates().to_list()
inst_list
# Out:
# ['906531', '907039']

# %%
list_of_dicts = np.concatenate(db_test['papers'].values)
list_of_dicts
# Out:
# array([{'recid': 35032, 'year': '1993', 'citation_count': 51, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '906531'},
#        {'recid': 373019, 'year': '1994', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '906531'},
#        {'recid': 366784, 'year': '1993', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '907039'},
#        {'recid': 369157, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '907039'},
#        {'recid': 401209, 'year': '1995', 'citation_count': 133, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 401209, 'year': '1995', 'citation_count': 133, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '907039'},
#        {'recid': 881104, 'year': '2011', 'citation_count': 23, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 1800448, 'year': '2020', 'citation_count': 8, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1322531, 'year': '2015', 'citation_count': 9, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1739816, 'year': '2020', 'citation_count': 9, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 901612, 'year': '2011', 'citation_count': 4, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 1811434, 'year': '2020', 'citation_count': 7, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 918734, 'year': '2013', 'citation_count': 35, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 918734, 'year': '2013', 'citation_count': 35, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 925032, 'year': '2012', 'citation_count': 47, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212538', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 925032, 'year': '2012', 'citation_count': 47, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212538', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 918193, 'year': '2011', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 918193, 'year': '2011', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 1415846, 'year': '2015', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1335492, 'year': '2017', 'citation_count': 12, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1080481, 'year': '2012', 'citation_count': 49, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '908938'},
#        {'recid': 1405429, 'year': '2018', 'citation_count': 10, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1729248, 'year': '2019', 'citation_count': 4, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1729248, 'year': '2019', 'citation_count': 4, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903067'},
#        {'recid': 1261866, 'year': '2014', 'citation_count': 1, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214146', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '908069'},
#        {'recid': 603318, 'year': '2003', 'citation_count': 68, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 603318, 'year': '2003', 'citation_count': 68, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 646314, 'year': '2004', 'citation_count': 290, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 646314, 'year': '2004', 'citation_count': 290, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1275575, 'year': '2013', 'citation_count': 2, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1347246, 'year': '2015', 'citation_count': 13, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212538', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 874978, 'year': '2012', 'citation_count': 4, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': '1214446', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 874978, 'year': '2012', 'citation_count': 4, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': '1214446', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '902701'},
#        {'recid': 1624384, 'year': '2018', 'citation_count': 11, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1475454, 'year': '2017', 'citation_count': 13, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1641722, 'year': '2018', 'citation_count': 13, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 585025, 'year': '2002', 'citation_count': 134, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1669779, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '908069'},
#        {'recid': 1233070, 'year': '2013', 'citation_count': 10, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 636707, 'year': '2003', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1212738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '908938'},
#        {'recid': 1324865, 'year': '2000', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '908938'},
#        {'recid': 550481, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '908938'},
#        {'recid': 1210429, 'year': '2014', 'citation_count': 12, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '908938'},
#        {'recid': 1473815, 'year': '2017', 'citation_count': 11, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 1508608, 'year': '2017', 'citation_count': 6, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 868425, 'year': '2010', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1213302', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 384965, 'year': '1994', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 672008, 'year': '2005', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 1299665, 'year': '2015', 'citation_count': 20, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 761367, 'year': '2007', 'citation_count': 4, 'primary_arxiv_category': [], 'journal_id': '1212279', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 701032, 'year': '2005', 'citation_count': 5, 'primary_arxiv_category': [], 'journal_id': '1212279', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 1310733, 'year': '2015', 'citation_count': 33, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1628640, 'year': '2018', 'citation_count': 7, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 1759249, 'year': '2020', 'citation_count': 16, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 528723, 'year': '2001', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 1393477, 'year': '2015', 'citation_count': 17, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1304361, 'year': '2014', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1243781', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 1409913, 'year': '2016', 'citation_count': 17, 'primary_arxiv_category': ['quant-ph'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 2062438, 'year': '2022', 'citation_count': 1, 'primary_arxiv_category': ['quant-ph'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 1745940, 'year': '2020', 'citation_count': 10, 'primary_arxiv_category': ['math-ph'], 'journal_id': '1214658', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 1745940, 'year': '2020', 'citation_count': 10, 'primary_arxiv_category': ['math-ph'], 'journal_id': '1214658', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 686272, 'year': '2005', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1213302', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 686272, 'year': '2005', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1213302', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 687263, 'year': '2005', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 687263, 'year': '2005', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 471900, 'year': '1998', 'citation_count': 74, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 425978, 'year': '1997', 'citation_count': 35, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 523512, 'year': '2000', 'citation_count': 63, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 912978, 'year': '2012', 'citation_count': 26, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 811328, 'year': '2009', 'citation_count': 1, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212279', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1477015, 'year': '2017', 'citation_count': 8, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1213635', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 472246, 'year': '1998', 'citation_count': 25, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 543865, 'year': '2000', 'citation_count': 7, 'primary_arxiv_category': ['astro-ph'], 'journal_id': '1214902', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 459236, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 406410, 'year': '1996', 'citation_count': 23, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 419668, 'year': '1997', 'citation_count': 14, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 590778, 'year': '2003', 'citation_count': 47, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 801902, 'year': '2009', 'citation_count': 15, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214424', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 687084, 'year': '2005', 'citation_count': 2, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 699293, 'year': '2005', 'citation_count': 7, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 711506, 'year': 'None', 'citation_count': 50, 'primary_arxiv_category': ['hep-th'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 389875, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 524254, 'year': '2000', 'citation_count': 62, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1776700, 'year': '2021', 'citation_count': 23, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1423055, 'year': '2016', 'citation_count': 6, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 535564, 'year': '2002', 'citation_count': 12, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1451633, 'year': '2016', 'citation_count': 21, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1202862, 'year': '2013', 'citation_count': 70, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1607552, 'year': '2018', 'citation_count': 8, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1841815, 'year': '2020', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1213635', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1636129, 'year': '2019', 'citation_count': 32, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1668941, 'year': '2018', 'citation_count': 22, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1446964, 'year': '2017', 'citation_count': 126, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 2087183, 'year': '2022', 'citation_count': 1, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1620685, 'year': '2018', 'citation_count': 16, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1634584, 'year': '2018', 'citation_count': 3, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 592813, 'year': '2002', 'citation_count': 3, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 926096, 'year': '2012', 'citation_count': 9, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212237', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 850610, 'year': '2010', 'citation_count': 36, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1253107, 'year': '2014', 'citation_count': 27, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 652677, 'year': '2004', 'citation_count': 3, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 742363, 'year': '2007', 'citation_count': 13, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212279', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 802986, 'year': '2011', 'citation_count': 9, 'primary_arxiv_category': ['physics.gen-ph'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 850318, 'year': '2010', 'citation_count': 8, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1213302', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 821861, 'year': '2011', 'citation_count': 86, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1494147, 'year': '2016', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1212279', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 559071, 'year': '2001', 'citation_count': 10, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 537344, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 553058, 'year': '2001', 'citation_count': 2, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214558', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 554307, 'year': '2001', 'citation_count': 7, 'primary_arxiv_category': ['astro-ph'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 541565, 'year': '2001', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1213302', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 511264, 'year': '2000', 'citation_count': 35, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 644206, 'year': '2004', 'citation_count': 14, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 558489, 'year': '2001', 'citation_count': 10, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 459168, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 433387, 'year': '1996', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1214735', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 415229, 'year': '1996', 'citation_count': 85, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 1818204, 'year': '2021', 'citation_count': 6, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 2083242, 'year': '2022', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1765078, 'year': '2021', 'citation_count': 5, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 537297, 'year': '2001', 'citation_count': 58, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 536809, 'year': '2001', 'citation_count': 101, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 588197, 'year': '2003', 'citation_count': 21, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 526395, 'year': '2000', 'citation_count': 14, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 645302, 'year': '2004', 'citation_count': 8, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 667381, 'year': '2004', 'citation_count': 3, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 650563, 'year': '2004', 'citation_count': 1, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 678616, 'year': '2005', 'citation_count': 33, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 808391, 'year': '2008', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1213302', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1419301, 'year': '2014', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1213635', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1113308, 'year': '2012', 'citation_count': 4, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 423180, 'year': '1997', 'citation_count': 16, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 400927, 'year': '1995', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 1301550, 'year': '2015', 'citation_count': 19, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1191425, 'year': '2013', 'citation_count': 12, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 618581, 'year': '2003', 'citation_count': 61, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 618581, 'year': '2003', 'citation_count': 61, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 1240086, 'year': '2014', 'citation_count': 14, 'primary_arxiv_category': ['quant-ph'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 452653, 'year': '1998', 'citation_count': 48, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 778466, 'year': '2008', 'citation_count': 52, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 778466, 'year': '2008', 'citation_count': 52, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 495524, 'year': '1999', 'citation_count': 27, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 584384, 'year': '2002', 'citation_count': 12, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 690686, 'year': '2006', 'citation_count': 132, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 690686, 'year': '2006', 'citation_count': 132, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 622148, 'year': '2003', 'citation_count': 35, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 622148, 'year': '2003', 'citation_count': 35, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 459143, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 459143, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '905835'},
#        {'recid': 1862134, 'year': '2021', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 418694, 'year': '1996', 'citation_count': 1, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 507699, 'year': '1999', 'citation_count': 7, 'primary_arxiv_category': [], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 733207, 'year': '2007', 'citation_count': 22, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212279', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 717495, 'year': '2007', 'citation_count': 1, 'primary_arxiv_category': ['hep-ph'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 456234, 'year': '1998', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1212738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 453337, 'year': '1997', 'citation_count': 10, 'primary_arxiv_category': [], 'journal_id': '1214843', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 450323, 'year': '1997', 'citation_count': 70, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 770705, 'year': '2007', 'citation_count': 6, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1213080', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 771124, 'year': '2008', 'citation_count': 7, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 759923, 'year': '2008', 'citation_count': 25, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 35032, 'year': '1993', 'citation_count': 51, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '906531'},
#        {'recid': 373019, 'year': '1994', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '906531'},
#        {'recid': 366784, 'year': '1993', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '907039'},
#        {'recid': 369157, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '907039'},
#        {'recid': 401209, 'year': '1995', 'citation_count': 133, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 401209, 'year': '1995', 'citation_count': 133, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '907039'},
#        {'recid': 881104, 'year': '2011', 'citation_count': 23, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 1800448, 'year': '2020', 'citation_count': 8, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1322531, 'year': '2015', 'citation_count': 9, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1739816, 'year': '2020', 'citation_count': 9, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 901612, 'year': '2011', 'citation_count': 4, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 1811434, 'year': '2020', 'citation_count': 7, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 918734, 'year': '2013', 'citation_count': 35, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 918734, 'year': '2013', 'citation_count': 35, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 925032, 'year': '2012', 'citation_count': 47, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212538', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 925032, 'year': '2012', 'citation_count': 47, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212538', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 918193, 'year': '2011', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903003'},
#        {'recid': 918193, 'year': '2011', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904697'},
#        {'recid': 1415846, 'year': '2015', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1335492, 'year': '2017', 'citation_count': 12, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1080481, 'year': '2012', 'citation_count': 49, 'primary_arxiv_category': ['astro-ph.CO'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '908938'},
# ...
#        {'recid': 1494147, 'year': '2016', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1212279', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 559071, 'year': '2001', 'citation_count': 10, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 537344, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 553058, 'year': '2001', 'citation_count': 2, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214558', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 554307, 'year': '2001', 'citation_count': 7, 'primary_arxiv_category': ['astro-ph'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 541565, 'year': '2001', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1213302', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 511264, 'year': '2000', 'citation_count': 35, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 644206, 'year': '2004', 'citation_count': 14, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 558489, 'year': '2001', 'citation_count': 10, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 459168, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 433387, 'year': '1996', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1214735', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 415229, 'year': '1996', 'citation_count': 85, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 1818204, 'year': '2021', 'citation_count': 6, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 2083242, 'year': '2022', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1765078, 'year': '2021', 'citation_count': 5, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 537297, 'year': '2001', 'citation_count': 58, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 536809, 'year': '2001', 'citation_count': 101, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 588197, 'year': '2003', 'citation_count': 21, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 526395, 'year': '2000', 'citation_count': 14, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 645302, 'year': '2004', 'citation_count': 8, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 667381, 'year': '2004', 'citation_count': 3, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 650563, 'year': '2004', 'citation_count': 1, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 678616, 'year': '2005', 'citation_count': 33, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 808391, 'year': '2008', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': '1213302', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1419301, 'year': '2014', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1213635', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1113308, 'year': '2012', 'citation_count': 4, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 423180, 'year': '1997', 'citation_count': 16, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 400927, 'year': '1995', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 1301550, 'year': '2015', 'citation_count': 19, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 1191425, 'year': '2013', 'citation_count': 12, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 618581, 'year': '2003', 'citation_count': 61, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 618581, 'year': '2003', 'citation_count': 61, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 1240086, 'year': '2014', 'citation_count': 14, 'primary_arxiv_category': ['quant-ph'], 'journal_id': '1214747', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 452653, 'year': '1998', 'citation_count': 48, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 778466, 'year': '2008', 'citation_count': 52, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 778466, 'year': '2008', 'citation_count': 52, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 495524, 'year': '1999', 'citation_count': 27, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 584384, 'year': '2002', 'citation_count': 12, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 690686, 'year': '2006', 'citation_count': 132, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 690686, 'year': '2006', 'citation_count': 132, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 622148, 'year': '2003', 'citation_count': 35, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '903125'},
#        {'recid': 622148, 'year': '2003', 'citation_count': 35, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214495', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 459143, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 459143, 'year': 'None', 'citation_count': 0, 'primary_arxiv_category': [], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '905835'},
#        {'recid': 1862134, 'year': '2021', 'citation_count': 0, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 418694, 'year': '1996', 'citation_count': 1, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287'},
#        {'recid': 507699, 'year': '1999', 'citation_count': 7, 'primary_arxiv_category': [], 'journal_id': '1214738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 733207, 'year': '2007', 'citation_count': 22, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1212279', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 717495, 'year': '2007', 'citation_count': 1, 'primary_arxiv_category': ['hep-ph'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 456234, 'year': '1998', 'citation_count': 1, 'primary_arxiv_category': [], 'journal_id': '1212738', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 453337, 'year': '1997', 'citation_count': 10, 'primary_arxiv_category': [], 'journal_id': '1214843', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 450323, 'year': '1997', 'citation_count': 70, 'primary_arxiv_category': [], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 770705, 'year': '2007', 'citation_count': 6, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1213080', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 771124, 'year': '2008', 'citation_count': 7, 'primary_arxiv_category': ['gr-qc'], 'journal_id': 'None', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'},
#        {'recid': 759923, 'year': '2008', 'citation_count': 25, 'primary_arxiv_category': ['gr-qc'], 'journal_id': '1214779', 'author_id': 'Daniel.Sudarsky.1', 'institution_id': '904287', 'rank': 'SENIOR', 'start_date': '1997', 'end_date': None, 'current': True, 'institution': 'Mexico U., ICN', 'country': 'Mexico'}],
#       dtype=object)

# %% [markdown]
# # Calculate citations

# %%
# DEPRECATED

# Get number of citations  

#def get_number_citations(name_of_country):
#    """
#    This is a function. 
#    """
#    # select the country
#    db=db_master[db_master['country']==name_of_country].reset_index(drop=True)
#    
#    # drop duplicates by record id as multiple authors in the dataframe 
#    # can contribute to the same paper.
#    # Notice that we include the citations of papers that do not necessarily have a 
#    # journal_id 
#    dp=pd.DataFrame( db.papers.apply(pd.Series).stack().to_list() ).drop_duplicates(subset='recid').reset_index(drop=True)
#    
#    # get citations
#    citations = dp['citation_count'].sum()
#    print(f"{name_of_country} = {citations} citations")
#    return citations

# %%
# calculate number of citations

def get_number_citations(country):
    """
    docs
    """
    # df with only the rows of the country
    db_country = db_master[db_master['country']==country].reset_index(drop=True)
    # select list of institutions of the given country
    inst_list = db_country['institution_id'].drop_duplicates().to_list()
    # define the list of dictionaries
    list_of_dicts = np.concatenate(db_country['papers'].values)
    
    # create a set to keep track of unique 'recid' values
    unique_recid_values = set()
    # create a new list to store the dictionaries with unique 'recid' values
    unique_dicts_list = []
    # create a list to store the indices of non-unique elements
    non_unique_indices = []
    # loop through the list of dictionaries and track the indices
    for index, d in enumerate(list_of_dicts):
        recid_value = d['recid']
        # check if the 'a' value is not already in the set (not a duplicate)
        if recid_value not in unique_recid_values:
            # if not, add it to the set and add the dictionary to the new list
            unique_recid_values.add(recid_value)
            unique_dicts_list.append(d)
        else:
            # if it's a duplicate, add the index to the non_unique_indices list
            non_unique_indices.append(index)
    
    # notice the typo in `instituion` in what follows
    papers_country = [element for element in unique_dicts_list if element['institution_id'] in inst_list]
    filtered_list_of_dicts = [item for item in list_of_dicts if item['institution_id'] in inst_list]
    
    seen_recids = set()
    filtered_data = []

    for item in filtered_list_of_dicts:
        if item['recid'] not in seen_recids:
            filtered_data.append(item)
            seen_recids.add(item['recid'])
            
    # filtered_data is the
    # list of the papers of a given country
    
    # now we calculate the citations
    total_citations = np.sum([elem['citation_count'] for elem in filtered_data])
    
    print(f"{country} = {total_citations} citations")
    return total_citations

# %%
def generate_number_citations_all():
    ans = {}
    for country in LA_countries:
        ans[country] = get_number_citations(country)
    return ans

citations = generate_number_citations_all();
# Out:
# Argentina = 107849 citations
# Bolivia = 211 citations
# Brazil = 341064 citations
# Chile = 150398 citations
# Colombia = 23877 citations
# Costa Rica = 7587 citations
# Cuba = 4351 citations
# Dominican Republic = 184 citations
# Ecuador = 1492 citations
# El Salvador = 26 citations
# Guatemala = 330 citations
# Honduras = 15 citations
# Mexico = 144645 citations
# Panama = 2 citations
# Paraguay = 57 citations
# Peru = 2335 citations
# Uruguay = 10693 citations
# Venezuela = 25259 citations

# %% [markdown]
# # Generate the histogram

# %%
# Population of each country

"""
Arrays account for 
- Argentina
- Bolivia
- Brazil
- Chile
- Colombia
- Costa Rica
- Cuba
- Dominican Republic
- Ecuador
- El Salvador
- Guatemala
- Honduras
- Mexico
- Panama
- Paraguay
- Peru
- Puerto Rico
- Uruguay
- Venezuela
"""

# population in millions of inhabitants
population = {element: None for element in LA_countries}

population['Argentina'] = 45.606
population['Bolivia'] = 11.833
population['Brazil'] = 213.993
population['Chile'] = 19.212
population['Colombia'] = 51.266
population['Costa Rica'] = 5.139
population['Cuba'] = 11.318
population['Dominican Republic'] = 10.954
population['Ecuador'] = 17.888
population['El Salvador'] = 6.158
population['Guatemala'] = 18.250
population['Honduras'] = 10.063
population['Mexico'] = 130.262
population['Panama'] = 4.382
population['Paraguay'] = 7.220
population['Peru'] = 33.359
#population['Puerto Rico'] = 2.828
population['Uruguay'] = 3.485
population['Venezuela'] = 28.705


# number of authors per country 
# taken from our own results
n_auth = {element: None for element in LA_countries}

n_auth['Argentina'] = 1984
n_auth['Bolivia'] = 50
n_auth['Brazil'] = 8456
n_auth['Chile'] = 2043
n_auth['Colombia'] = 723
n_auth['Costa Rica'] = 29
n_auth['Cuba'] = 236
n_auth['Dominican Republic'] = 1
n_auth['Ecuador'] = 66
n_auth['El Salvador'] = 6
n_auth['Guatemala'] = 32
n_auth['Honduras'] = 11
n_auth['Mexico'] = 3876
n_auth['Panama'] = 3
n_auth['Paraguay'] = 5
n_auth['Peru'] = 156
#n_auth['Puerto Rico'] = 10
n_auth['Uruguay'] = 87
n_auth['Venezuela'] = 370

# %%
citations_pc = {k: citations[k] / population[k] for k in citations}

# %%
citations_pc
# Out:
# {'Argentina': 2364.7984914265667,
#  'Bolivia': 17.831488210935518,
#  'Brazil': 1593.8091432897338,
#  'Chile': 7828.336456381428,
#  'Colombia': 465.7472788982952,
#  'Costa Rica': 1476.3572679509632,
#  'Cuba': 384.43187842374977,
#  'Dominican Republic': 16.797516888807742,
#  'Ecuador': 83.40787119856887,
#  'El Salvador': 4.222150048717116,
#  'Guatemala': 18.08219178082192,
#  'Honduras': 1.4906091622776507,
#  'Mexico': 1110.4159309698914,
#  'Panama': 0.4564125969876769,
#  'Paraguay': 7.894736842105264,
#  'Peru': 69.99610300068946,
#  'Uruguay': 3068.2926829268295,
#  'Venezuela': 879.9512280090577}

# %%
citations_per_author = {k: citations[k] / n_auth[k] for k in citations}

# %%
citations_per_author
# Out:
# {'Argentina': 54.359375,
#  'Bolivia': 4.22,
#  'Brazil': 40.333964049195835,
#  'Chile': 73.61625061184533,
#  'Colombia': 33.024896265560166,
#  'Costa Rica': 261.62068965517244,
#  'Cuba': 18.4364406779661,
#  'Dominican Republic': 184.0,
#  'Ecuador': 22.606060606060606,
#  'El Salvador': 4.333333333333333,
#  'Guatemala': 10.3125,
#  'Honduras': 1.3636363636363635,
#  'Mexico': 37.31811145510836,
#  'Panama': 0.6666666666666666,
#  'Paraguay': 11.4,
#  'Peru': 14.967948717948717,
#  'Uruguay': 122.9080459770115,
#  'Venezuela': 68.26756756756757}

# %% [markdown]
# # Generate histogram of citations per capita

# %%
def gen_citations_pc():

    labels = LA_countries
    data = citations_pc.values()

    x = np.arange(len(labels))  # the label locations
    width = 0.35  # the width of the bars
    fig, ax = plt.subplots()
    ax.bar(x, data, width)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.grid(True)
    ax.set_ylabel('Value')
    ax.set_title('Citations per million people')
    ax.tick_params(axis='x', rotation=90)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_axisbelow(True)

    fig.tight_layout()
    fig.savefig(f'../figures/citations/all_citations_pc.pdf', 
                dpi=150, bbox_inches = 'tight')

    plt.show()
    
gen_citations_pc()

# %%
def gen_citations_total():

    labels = LA_countries
    data = citations.values()

    x = np.arange(len(labels))  # the label locations
    width = 0.35  # the width of the bars
    fig, ax = plt.subplots()
    ax.bar(x, data, width)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.grid(True)
    ax.set_ylabel('Value')
    ax.set_title('Total citations')
    ax.tick_params(axis='x', rotation=90)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_axisbelow(True)
    ax.set_yscale('log')

    fig.tight_layout()
    fig.savefig(f'../figures/citations/all_citations_total.pdf', 
                dpi=150, bbox_inches = 'tight')

    plt.show()
    
gen_citations_total()

# %% [markdown]
# # Generate histogram of citations per author

# %%
def gen_citations_per_author():
    
    # without the anomaly in DR
    labels = np.array(LA_countries)
    data = np.array(list(citations_per_author.values()))
    
    # remove the DR anomaly
    #new_labels = np.delete(np.copy(labels), 7)
    #new_data = np.delete(np.copy(data), 7)
    new_labels = labels
    new_data = data
        
    x = np.arange(len(new_labels))  # the label locations
    #x = np.arange(len(labels))  # the label locations
    width = 0.35  # the width of the bars
    fig, ax = plt.subplots()
    ax.bar(x, new_data, width)
    #ax.bar(x, data, width)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.grid(True)
    ax.set_ylabel('Value')
    ax.set_title('Citations per author')
    ax.tick_params(axis='x', rotation=90)
    ax.set_xticks(x)
    ax.set_xticklabels(new_labels)
    #ax.set_xticklabels(labels)
    ax.set_axisbelow(True)

    fig.tight_layout()
    fig.savefig(f'../figures/citations/all_citations_per_author.pdf', 
                dpi=150, bbox_inches = 'tight')

    plt.show()
    
gen_citations_per_author()

# %% [markdown]
# # Correlation with GDP

# %%
# GDP in R&D of each country

"""
Arrays account for 
- Argentina
- Bolivia
- Brazil
- Chile
- Colombia
- Costa Rica
- Cuba
- Dominican Republic
- Ecuador
- El Salvador
- Guatemala
- Honduras
- Mexico
- Panama
- Paraguay
- Peru
- Puerto Rico
- Uruguay
- Venezuela
"""

# GDPs taken from the World Bank
gdp = {element: None for element in LA_countries}

gdp['Argentina'] = 0.46
gdp['Bolivia'] = 0.16
gdp['Brazil'] = 1.21
gdp['Chile'] = 0.34
gdp['Colombia'] = 0.29
gdp['Costa Rica'] = 0.37
gdp['Cuba'] = 0.52
gdp['Dominican Republic'] = None # no info from the World Bank
gdp['Ecuador'] = 0.44
gdp['El Salvador'] = 0.17
gdp['Guatemala'] = 0.03
gdp['Honduras'] = 0.04
gdp['Mexico'] = 0.3
gdp['Panama'] = 0.15
gdp['Paraguay'] = 0.14
gdp['Peru'] = 0.17
#gdp['Puerto Rico'] = 0.43
gdp['Uruguay'] = 0.48
gdp['Venezuela'] = 0.34

# %% [markdown]
# # Formatting parameters of the plot

# %%
colour_list = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', 
               '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', 
               '#008080', '#e6beff', '#9a6324', '#800000', 
               '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#ffffff', '#000000']

# take care of the ValueErrors if no data is provided by the World Bank
def calculate_ratios(dict1, dict2):
    ratios = {}
    for key in dict1:
        if dict2[key] is not None:
            value1 = dict1[key]
            value2 = dict2[key]
            ratio = value1 / value2
            ratios[key] = ratio
    return ratios

# %%
def gen_citations_sp():
    
    fig, ax = plt.subplots()

    data = list(zip(LA_countries, 
                    gdp.values(), 
                    citations_pc.values(), 
                    population.values()))
    
    for i in range(len(data)):
        # take care of the exceptions
        if data[i][1] is not None:
            x = data[i][1]
            y = data[i][2]
            r = data[i][3]  #radius
            #ax.scatter(x, y, label=data[i][0], s=10*r, alpha=0.8, c=colour_list[i], edgecolors='none')
            ax.scatter(x, y, label=data[i][0], s=200, alpha=0.8, c=colour_list[i], edgecolors='none')
    
    # format
    ax.set_xlabel('Percent of GDP')
    ax.set_ylabel('Value')
    ax.set_title('Citations per million people')

    ax.grid(True)
    ax.set_axisbelow(True)
    lgnd = ax.legend()
    handles = lgnd.legendHandles

    for handle in handles:
        handle._sizes = [50]

    # Specify the legend location outside the plot
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    fig.savefig(f'../figures/citations/all_citations_sp.pdf', 
                dpi=150, bbox_inches = 'tight')

    plt.show()
    
gen_citations_sp()
