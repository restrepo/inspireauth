# %%
import sys
import os

# Get the absolute path to the scripts directory
scripts_dir = os.path.abspath(os.path.join('..', 'scripts'))

# Add the scripts directory to the Python path
if scripts_dir not in sys.path:
    sys.path.append(scripts_dir)

# %%
from loading import load_data
from processing import generate_dataframe

# %%
# load master database
db_master = load_data()

# %%
# generate dataframe of the publications of Mexico
df_mexico = generate_dataframe(db_master, country="Mexico")

# %%
df_mexico
# Out:
#         recid  year  citation_count primary_arxiv_category journal_id  \
# 0      648497  2004              24             [astro-ph]    1214843
# 1      699153  2005              12             [astro-ph]    1214577
# 2      692326  2005              16             [astro-ph]    1214902
# 3      665204  2005              47             [astro-ph]    1214866
# 4      674346  2005              44             [astro-ph]    1648534
# ...       ...   ...             ...                    ...        ...
# 9582   848758  2010              24          [astro-ph.CO]    1648534
# 9583  1478735  2016              13          [astro-ph.HE]       None
# 9584  1261077  2014               4          [astro-ph.CO]    1214577
# 9585   662701  2005               7             [astro-ph]    1214577
# 9586  1742049  2020             119          [astro-ph.HE]    1214902
#
#                author_id institution_id rank start_date end_date institution  \
# 0           R.Gonzalez.2         908050  NaN        NaN      NaN         NaN
# 1           R.Gonzalez.2         908050  NaN        NaN      NaN         NaN
# 2           R.Gonzalez.2         908050  NaN        NaN      NaN         NaN
# 3           R.Gonzalez.2         908050  NaN        NaN      NaN         NaN
# 4           R.Gonzalez.2         908050  NaN        NaN      NaN         NaN
# ...                  ...            ...  ...        ...      ...         ...
# 9582         M.Plionis.2         907342  NaN        NaN      NaN         NaN
# 9583    J.Leon.Tavares.4         907342  NaN        NaN      NaN         NaN
# 9584  F.Rosales.Ortega.1         907342  NaN        NaN      NaN         NaN
# 9585      E.Mendizabal.1         907342  NaN        NaN      NaN         NaN
# 9586           A.Batta.1         907342  NaN        NaN      NaN         NaN
#
#      country current
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN
# ...      ...     ...
# 9582     NaN     NaN
# 9583     NaN     NaN
# 9584     NaN     NaN
# 9585     NaN     NaN
# 9586     NaN     NaN
#
# [9584 rows x 13 columns]

# %%
# TODO: stress test
